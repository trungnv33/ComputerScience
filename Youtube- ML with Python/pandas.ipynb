# %%
import pandas as pd

# %%
df= pd.read_csv('ThongKePhanTuSuCo.csv')

# %%
df = df.head(10)
df
# Out:
#       Mã Ticket                                            Tiêu đề  \
# 0  SC0108180001               [FTN-HN8]- HNIP55003GC57- PON 8 down
# 1  SC0108180002  [SCC]Ghi nhận sự cố hạ tầng "INF-VPC-VPCP01501...
# 2  SC0108180003  [FTN-BTHT1] HNIP01002HW58-20.25.14.23 G0/0/18 ...
# 3  SC0108180004  [SCC]Ghi nhận sự cố hạ tầng BTHT1-HCMP07401PWE...
# 4  SC0108180005  [SCC]Ghi nhận sự cố hạ tầng INF-BNH-BNHM00101P...
# 5  SC0108180006  [SCC]Ghi nhận sự cố hạ tầng INF-DNG-DNGP14101P...
# 6  SC0108180007  [SCC]Ghi nhận sự cố hạ tầng INF-BNH-BNHP02001P...
# 7  SC0108180008  [SCC]Ghi nhận sự cố hạ tầng INF-BNH-BNHP05701P...
# 8  SC0108180009  [SCC]Ghi nhận sự cố hạ tầng INF-HPG-HPGP06701P...
# 9  SC0108180011  [SCC]Ghi nhận sự cố hạ tầng "INF-NDH-NDHM00102...
#
#         Nhóm phần tử        Phần tử  Loại dịch vụ Loại khách hàng  \
# 0    Hệ Thống Access       Port PON  1. BroadBand             PON
# 1    Hệ Thống Access          Nguồn          None            None
# ...

# %%
g = df.groupby ('Phần tử').sum()

# %%
g
# Out:
#                Cấp độ  Số lượng KH  Tổng TG xử lý  TG gián đoạn  Mức ưu tiên  \
# Phần tử
# KÊNH BACKBONE       3            0           9322           541            0
# Nguồn              16            0           2199          2239            8
# Port PON            1           17            773           782            0
#
#                Số lượng KH PayTV  Loại hỗ trợ  Hình thái lỗi  Phân đoạn lỗi  \
# Phần tử
# KÊNH BACKBONE                  0          0.0            0.0            0.0
# Nguồn                          0          0.0            0.0            0.0
# Port PON                       4          0.0            0.0            0.0
#
#                Node lỗi  Tổng thời gian thực
# Phần tử
# KÊNH BACKBONE       0.0                   86
# Nguồn               0.0                   11
# Port PON            0.0                    1

# %%
df.pivot(index ='Cấp độ',columns = "Mã Ticket")
# Out:
#                                         Tiêu đề  \
# Mã Ticket                          SC0108180001
# Cấp độ
# 1          [FTN-HN8]- HNIP55003GC57- PON 8 down
# 2                                           NaN
# 3                                           NaN
#
#                                                               \
# Mã Ticket                                       SC0108180002
# Cấp độ
# 1                                                        NaN
# 2          [SCC]Ghi nhận sự cố hạ tầng "INF-VPC-VPCP01501...
# 3                                                        NaN
#
#                                                               \
# Mã Ticket                                       SC0108180003
# Cấp độ
# 1                                                        NaN
# 2                                                        NaN
# 3          [FTN-BTHT1] HNIP01002HW58-20.25.14.23 G0/0/18 ...
#
#                                                               \
# ...
